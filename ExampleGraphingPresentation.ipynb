# %% [markdown]
# # this is my example, you can build your own

# %%
# imports

#data things
import numpy as np
import panadas as pd
import random

#graphing
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
